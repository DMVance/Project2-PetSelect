# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
INTAKES_URL = "https://data.austintexas.gov/resource/wter-evkm.json"
PARAMS = {
    "animal_type": "Dog",
    "$$app_token": "aBq5AbxH1zKfProvzcMh0h4Dm"
}

# %%
r = requests.get(INTAKES_URL, params=PARAMS)
df = pd.DataFrame(r.json())
df = df.drop(columns=['datetime2']).fillna('None')
len(df)
# Out:
# 1000

# %%
df.head(10)
# Out:
#   animal_id                 datetime                      found_location  \
# 0   A826026  2020-11-17T17:25:00.000  5347 Mission Circle in Austin (TX)
# 1   A826027  2020-11-17T17:25:00.000  5347 Mission Circle in Austin (TX)
# 2   A826025  2020-11-17T17:25:00.000  5347 Mission Circle in Austin (TX)
# 3   A826016  2020-11-17T16:21:00.000     5716 Malarkey Rd in Austin (TX)
# 4   A826023  2020-11-17T17:25:00.000  5347 Mission Circle in Austin (TX)
# 5   A826024  2020-11-17T17:25:00.000  5347 Mission Circle in Austin (TX)
# 6   A826022  2020-11-17T17:25:00.000  5347 Mission Circle in Austin (TX)
# 7   A826014  2020-11-17T16:01:00.000       4501 Depew Ave in Austin (TX)
# 8   A826011  2020-11-17T15:58:00.000    1071 Clayton Lane in Austin (TX)
# 9   A826004  2020-11-17T15:12:00.000  12102 Clickett Cove in Austin (TX)
#
#   intake_type intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0       Stray           Normal         Dog   Intact Female         1 month
# 1       Stray           Normal         Dog   Intact Female         1 month
# 2       Stray           Normal         Dog     Intact Male         1 month
# 3       Stray           Normal         Dog   Intact Female         2 years
# 4       Stray           Normal         Dog     Intact Male         1 month
# 5       Stray           Normal         Dog   Intact Female         1 month
# 6       Stray           Normal         Dog   Intact Female         3 years
# 7       Stray           Normal         Dog     Intact Male         2 years
# 8       Stray             Sick         Dog         Unknown        6 months
# 9       Stray          Nursing         Dog   Intact Female         2 years
#
#                                     breed                color  name
# 0                                Pit Bull                Black  None
# 1                                Pit Bull        Brown Brindle  None
# 2                                Pit Bull                Black  None
# 3      Chihuahua Shorthair/Boston Terrier           Gray/White  None
# 4                                Pit Bull                Black  None
# 5                                Pit Bull                Black  None
# 6                                Pit Bull                Black  None
# 7  Australian Shepherd/Labrador Retriever                Black  None
# 8                           Catahoula Mix  Brown Brindle/White  None
# 9                  Labrador Retriever Mix             Tricolor  None

# %%
# =============
# DATA CLEANING
# =============
 
# Create empty lists for new columns
intake_datetime = []
found_address = []
found_city = []
found_state = []
sex = []
birthday = []
age = []
primary_breed = []
secondary_breed = []
mixed_breed = []
primary_color = []
secondary_color = []
name = []

for i in df.index:
    # Clean datetime column
    intake_dt = datetime.strptime(df.iloc[i]['datetime'].replace(".000", ""), '%Y-%m-%dT%H:%M:%S')
    intake_datetime.append(intake_dt)

    # Clean location column
    if len(df.iloc[i]['found_location'].split(" in ")) > 1:
        found_address.append(df.iloc[i]['found_location'].split(" in ")[0])
        found_city.append(df.iloc[i]['found_location'].split(" in ")[1].split(" (")[0])
        found_state.append(df.iloc[i]['found_location'].split(" in ")[1].split(" (")[1].replace(")", ""))
    elif "(TX)" in df.iloc[i]['found_location'].split(" in ")[0]:
        found_address.append('None')
        found_city.append(df.iloc[i]['found_location'].split(" in ")[0].split(" (")[0])
        found_state.append(df.iloc[i]['found_location'].split(" in ")[0].split(" (")[1].replace(")", ""))
    else:
        found_address.append(df.iloc[i]['found_location'])
        found_city.append('None')
        found_state.append('None')

    # Clean sex column
    sex.append(df.iloc[i]['sex_upon_intake'].replace("Intact ", "").replace("Neutered ", "").replace("Spayed ", ""))

    # Clean age upon intake column
    intake_age = df.iloc[i]['age_upon_intake'].split(" ")
    if intake_age[0].isnumeric():
        num = int(intake_age[0])
    else:
        num = "Unknown"
    if len(intake_age) > 1:
        duration = (
            intake_age[1]
            .replace("years", "year").replace("year", "years")
            .replace("months", "month").replace("month", "months")
            .replace("weeks", "week").replace("week", "weeks")
            .replace("days", "day").replace("day", "days")
            )
    else:
        duration = "Unknown"
    # Determine birthday
    if num == "Unknown" or duration == "Unknown":
        bday = "Unknown"
        birthday.append(bday)
    else:
        bday = intake_dt - relativedelta(**{duration: num})
        birthday.append(bday)
    # Determine age as of today's date
    if isinstance(intake_dt, datetime) and isinstance(bday, datetime):
        age_today = relativedelta(datetime.today(), bday)
        age.append(age_today)
    else:
        age.append("Unknown")
    
    # Clean breed column
    if len(df.iloc[i]['breed'].split("/")) > 1:
        primary_breed.append(df.iloc[i]['breed'].split("/")[0])
        secondary_breed.append(df.iloc[i]['breed'].split("/")[1])
        mixed_breed.append(True)
    else:
        primary_breed.append(df.iloc[i]['breed'])
        secondary_breed.append('None')
        mixed_breed.append(False)

    # Clean color column
    if len(df.iloc[i]['color'].split("/")) > 1:
        primary_color.append(df.iloc[i]['color'].split("/")[0])
        secondary_color.append(df.iloc[i]['color'].split("/")[1])
    else:
        primary_color.append(df.iloc[i]['color'])
        secondary_color.append('None')

    # Clean name column
    name.append(df.iloc[i]['name'].replace("*", ""))

# Compile clean dataframe
df2 = pd.DataFrame({
    "animal_id": df["animal_id"],
    "intake_datetime": intake_datetime,
    "found_address": found_address,
    "found_city": found_city,
    "found_state": found_state,
    "intake_type": df["intake_type"],
    "intake_condition": df["intake_condition"],
    "sex": sex,
    "birthday": birthday,
    "age": age,
    "mixed_breed": mixed_breed, 
    "primary_breed": primary_breed, 
    "secondary_breed": secondary_breed,
    "primary_color": primary_color,
    "secondary_color": secondary_color,
    "name": name, 
    })

df2.head(20)
# Out:
#    animal_id     intake_datetime            found_address found_city  \
# 0    A826026 2020-11-17 17:25:00      5347 Mission Circle     Austin
# 1    A826027 2020-11-17 17:25:00      5347 Mission Circle     Austin
# 2    A826025 2020-11-17 17:25:00      5347 Mission Circle     Austin
# 3    A826016 2020-11-17 16:21:00         5716 Malarkey Rd     Austin
# 4    A826023 2020-11-17 17:25:00      5347 Mission Circle     Austin
# 5    A826024 2020-11-17 17:25:00      5347 Mission Circle     Austin
# 6    A826022 2020-11-17 17:25:00      5347 Mission Circle     Austin
# 7    A826014 2020-11-17 16:01:00           4501 Depew Ave     Austin
# 8    A826011 2020-11-17 15:58:00        1071 Clayton Lane     Austin
# 9    A826004 2020-11-17 15:12:00      12102 Clickett Cove     Austin
# 10   A825839 2020-11-13 12:51:00                     None     Austin
# 11   A825840 2020-11-13 12:51:00                     None     Austin
# 12   A825785 2020-11-13 07:36:00       5701 Johnny Morris     Austin
# 13   A826003 2020-11-17 13:53:00            Cherry Hollow     Travis
# 14   A648265 2020-11-17 12:38:00                     None     Austin
# 15   A803141 2020-11-17 13:30:00  2615 Crystal Bend Drive     Travis
# 16   A819676 2020-07-02 18:29:00           15419 Giese Ln      Manor
# 17   A825851 2020-11-13 15:11:00            Alemoor Drive     Austin
# 18   A825847 2020-11-13 14:24:00         3101 Loyola Lane     Austin
# 19   A819676 2020-11-17 13:37:00                     None     Austin
#
#    found_state      intake_type intake_condition      sex  \
# 0           TX            Stray           Normal   Female
# 1           TX            Stray           Normal   Female
# 2           TX            Stray           Normal     Male
# 3           TX            Stray           Normal   Female
# 4           TX            Stray           Normal     Male
# 5           TX            Stray           Normal   Female
# 6           TX            Stray           Normal   Female
# 7           TX            Stray           Normal     Male
# 8           TX            Stray             Sick  Unknown
# 9           TX            Stray          Nursing   Female
# 10          TX  Owner Surrender           Normal     Male
# 11          TX  Owner Surrender           Normal     Male
# 12          TX            Stray           Normal     Male
# 13          TX            Stray           Normal     Male
# 14          TX  Owner Surrender          Injured     Male
# 15          TX            Stray           Normal   Female
# 16          TX            Stray           Normal   Female
# 17          TX            Stray           Normal   Female
# 18          TX            Stray           Normal   Female
# 19          TX  Owner Surrender           Normal   Female
#
#                birthday                                                age  \
# 0   2020-10-17 17:25:00  relativedelta(months=+1, hours=+22, minutes=+5...
# 1   2020-10-17 17:25:00  relativedelta(months=+1, hours=+22, minutes=+5...
# 2   2020-10-17 17:25:00  relativedelta(months=+1, hours=+22, minutes=+5...
# 3   2018-11-17 16:21:00  relativedelta(years=+2, hours=+23, minutes=+55...
# 4   2020-10-17 17:25:00  relativedelta(months=+1, hours=+22, minutes=+5...
# 5   2020-10-17 17:25:00  relativedelta(months=+1, hours=+22, minutes=+5...
# 6   2017-11-17 17:25:00  relativedelta(years=+3, hours=+22, minutes=+51...
# 7   2018-11-17 16:01:00  relativedelta(years=+2, days=+1, minutes=+15, ...
# 8   2020-05-17 15:58:00  relativedelta(months=+6, days=+1, minutes=+18,...
# 9   2018-11-17 15:12:00  relativedelta(years=+2, days=+1, hours=+1, min...
# 10  2020-02-13 12:51:00  relativedelta(months=+9, days=+5, hours=+3, mi...
# 11  2020-02-13 12:51:00  relativedelta(months=+9, days=+5, hours=+3, mi...
# 12  2020-05-13 07:36:00  relativedelta(months=+6, days=+5, hours=+8, mi...
# 13  2014-11-17 13:53:00  relativedelta(years=+6, days=+1, hours=+2, min...
# 14  2013-11-17 12:38:00  relativedelta(years=+7, days=+1, hours=+3, min...
# 15  2018-11-17 13:30:00  relativedelta(years=+2, days=+1, hours=+2, min...
# 16  2018-07-02 18:29:00  relativedelta(years=+2, months=+4, days=+15, h...
# 17  2018-11-13 15:11:00  relativedelta(years=+2, days=+5, hours=+1, min...
# 18  2018-11-13 14:24:00  relativedelta(years=+2, days=+5, hours=+1, min...
# 19  2018-11-17 13:37:00  relativedelta(years=+2, days=+1, hours=+2, min...
#
#     mixed_breed            primary_breed     secondary_breed  primary_color  \
# 0         False                 Pit Bull                None          Black
# 1         False                 Pit Bull                None  Brown Brindle
# 2         False                 Pit Bull                None          Black
# 3          True      Chihuahua Shorthair      Boston Terrier           Gray
# 4         False                 Pit Bull                None          Black
# 5         False                 Pit Bull                None          Black
# 6         False                 Pit Bull                None          Black
# 7          True      Australian Shepherd  Labrador Retriever          Black
# 8         False            Catahoula Mix                None  Brown Brindle
# 9         False   Labrador Retriever Mix                None       Tricolor
# 10         True      Chihuahua Shorthair         Rat Terrier            Tan
# 11         True      Chihuahua Shorthair         Rat Terrier            Tan
# 12        False  Chihuahua Shorthair Mix                None      Chocolate
# 13        False        Yorkshire Terrier                None          Brown
# 14        False  Chihuahua Shorthair Mix                None            Tan
# 15        False           Siberian Husky                None          Black
# 16         True                Chow Chow      Siberian Husky          Black
# 17        False            Alaskan Husky                None       Tricolor
# 18        False       Labrador Retriever                None         Yellow
# 19         True                Chow Chow      Siberian Husky          Black
#
#    secondary_color    name
# 0             None    None
# 1             None    None
# 2             None    None
# 3            White    None
# 4             None    None
# 5             None    None
# 6             None    None
# 7             None    None
# 8            White    None
# 9             None    None
# 10           White    Ford
# 11           White   Brahm
# 12             Tan  Anubis
# 13            None    None
# 14           Cream    Toby
# 15           White     Sky
# 16           Brown    Maya
# 17            None   Zelda
# 18            None   Ellie
# 19           Brown    Maya

# %%
# Extract age as a string of years, months, weeks (sample for the first 20 rows in df2)
[f"{age.years} years, {age.months} months, {age.weeks} weeks" for age in df2.head(20)['age'] if isinstance(age, relativedelta)]
# Out:
# ['0 years, 1 months, 0 weeks',
#  '0 years, 1 months, 0 weeks',
#  '0 years, 1 months, 0 weeks',
#  '2 years, 0 months, 0 weeks',
#  '0 years, 1 months, 0 weeks',
#  '0 years, 1 months, 0 weeks',
#  '3 years, 0 months, 0 weeks',
#  '2 years, 0 months, 0 weeks',
#  '0 years, 6 months, 0 weeks',
#  '2 years, 0 months, 0 weeks',
#  '0 years, 9 months, 0 weeks',
#  '0 years, 9 months, 0 weeks',
#  '0 years, 6 months, 0 weeks',
#  '6 years, 0 months, 0 weeks',
#  '7 years, 0 months, 0 weeks',
#  '2 years, 0 months, 0 weeks',
#  '2 years, 4 months, 2 weeks',
#  '2 years, 0 months, 0 weeks',
#  '2 years, 0 months, 0 weeks',
#  '2 years, 0 months, 0 weeks']
